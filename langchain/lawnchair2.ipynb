# %%
pip install llama-cpp-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.embeddings import LlamaCppEmbeddings

llama = LlamaCppEmbeddings(model_path="C:/Users/shafi/.cache/lm-studio/models/TheBloke/CodeLlama-13B-GGUF/codellama-13b.Q5_K_M.gguf")

text = "This is a test document."

query_result = llama.embed_query(text)

doc_result = llama.embed_documents([text])
# Out:
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 0 | VSX = 0 |

# %%
doc_result
# Out:
# [[0.6739256978034973,
#   -0.26034316420555115,
#   0.3897947669029236,
#   1.0269033908843994,
#   0.497280091047287,
#   -0.15289966762065887,
#   -1.194287657737732,
#   0.01676766946911812,
#   0.8422711491584778,
#   0.2570183277130127,
#   0.0028103142976760864,
#   0.7583792209625244,
#   1.010737657546997,
#   -1.0039054155349731,
#   -0.643295407295227,
#   0.053653400391340256,
#   0.21799565851688385,
#   -0.576503574848175,
#   1.5854220390319824,
#   0.6608981490135193,
#   0.5086560845375061,
#   0.09030715376138687,
#   -0.019843917340040207,
#   0.8624656200408936,
#   -0.05333727225661278,
#   0.28810766339302063,
#   -0.178897887468338,
#   -0.8295955061912537,
#   -0.6045741438865662,
#   -0.3292880654335022,
#   0.7915969491004944,
#   -0.7281678915023804,
#   -0.5146332383155823,
#   0.8461390733718872,
#   -2.370283365249634,
#   -0.8209434151649475,
#   -0.4654526710510254,
#   -0.1607334464788437,
#   1.535093903541565,
#   4.768598556518555,
# ...

# %%
template = """Question: {question}

Answer: Let's work this out in a step by step way to be sure we have the right answer."""

prompt = PromptTemplate(template=template, input_variables=["question"])

# %%
# Callbacks support token-wise streaming
callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])

# %%
# Make sure the model path is correct for your system!
llm = LlamaCpp(
    model_path="C:/Users/shafi/.cache/lm-studio/models/TheBloke/CodeLlama-13B-GGUF/codellama-13b.Q5_K_M.gguf",
    temperature=0.75,
    max_tokens=2000,
    top_p=1,
    callback_manager=callback_manager, 
    verbose=True, # Verbose is required to pass to the callback manager
)
# Out:
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 0 | VSX = 0 |

# %%
prompt = """
Question: An application that lists all of the numbers from 1 to 1,000,000 that are prime numbers
"""
llm(prompt)
# Out:
# Llama.generate: prefix-match hit
# I need an application that will list all of the numbers from 1 to 1,000,000 that are prime numbers.
# What I have done so far is this:
# \begin{code}
# #include <stdio.h>
# int x[];
# void display_array(x)) {
#         for (i = 0; i < 26; ++i) {
#                     printf("%c", x[i]));
#                                     }
#                                                      }
#                      void main() {
#          int x[];
#        int i;
#
#                      enter code here
# \end{code}
# This is what I have done so far.  I need help with this.  I am having difficulties with it. I need help with this and I need help with this.
# Comment: Is this homework? What have you tried? Where are you stuck? Please read [ask] and show your research effort, and also tell us a bit about what you want to do.
# ...
